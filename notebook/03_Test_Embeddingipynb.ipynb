# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
metadata = pd.read_csv("/content/drive/MyDrive/skripsi_nau/metadata/naudataset.csv")
print(metadata.shape)

metadata.head()
# Out:
# (6609, 6)
#    id  nama_gambar            aktivitas warna_dominan hijab undertone
# 0   1  img0001.jpg  coffee_shop_hopping         beige    ya   neutral
# 1   2  img0002.jpg  coffee_shop_hopping         beige    ya   neutral
# 2   3  img0003.jpg  coffee_shop_hopping         beige    ya   neutral
# 3   4  img0004.jpg  coffee_shop_hopping         beige    ya   neutral
# 4   5  img0005.jpg  coffee_shop_hopping         beige    ya   neutral

# %%
IMAGE_FOLDER = "/content/drive/MyDrive/skripsi_nau/dataset/"

# %%
metadata["image_path"] = metadata["nama_gambar"].apply(
    lambda x: os.path.join(IMAGE_FOLDER, x)
)

# %%
missing = metadata[
    ~metadata["image_path"].apply(os.path.exists)
]

print(len(missing))
# Out:
# 161

# %%
missing[["nama_gambar", "image_path"]].head(20)
# Out:
#      nama_gambar                                         image_path
# 122  img0123.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 123  img0124.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 126  img0127.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 128  img0129.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 129  img0130.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 130  img0131.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 132  img0133.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 133  img0134.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 135  img0136.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 141  img0142.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 143  img0144.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 146  img0147.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# 249  img0250.jpg  /content/drive/MyDrive/skripsi_nau/dataset/img...
# ...

# %%
import os

image_files = [
    f for f in os.listdir(IMAGE_FOLDER)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
]

print("Jumlah gambar di folder:", len(image_files))
print("Jumlah metadata:", len(metadata))
# Out:
# Jumlah gambar di folder: 6468
# Jumlah metadata: 6609

# %%
missing["nama_gambar"].tolist()[:20]
# Out:
# ['img0123.jpg',
#  'img0124.jpg',
#  'img0127.jpg',
#  'img0129.jpg',
#  'img0130.jpg',
#  'img0131.jpg',
#  'img0133.jpg',
#  'img0134.jpg',
#  'img0136.jpg',
#  'img0142.jpg',
#  'img0144.jpg',
#  'img0147.jpg',
#  'img0250.jpg',
#  'img0251.jpg',
#  'img0775.jpg',
#  'img0776.jpg',
#  'img0777.jpg',
#  'img0778.jpg',
#  'img0779.jpg',
#  'img0780.jpg']

# %%
import os
import pandas as pd

# Load metadata
metadata = pd.read_csv("/content/drive/MyDrive/skripsi_nau/metadata/naudataset.csv")

# Ambil semua nama file di folder dataset
image_files = set(os.listdir(IMAGE_FOLDER))

# Filter metadata
metadata_clean = metadata[
    metadata["nama_gambar"].isin(image_files)
].reset_index(drop=True)

print("Metadata awal :", len(metadata))
print("Metadata baru :", len(metadata_clean))
print("Data yang dibuang :", len(metadata) - len(metadata_clean))
# Out:
# Metadata awal : 6609
# Metadata baru : 6448
# Data yang dibuang : 161

# %%
metadata_clean.to_csv(
    "/content/drive/MyDrive/skripsi_nau/metadata/naudataset_clean.csv",
    index=False
)

# %%
metadata = pd.read_csv("/content/drive/MyDrive/skripsi_nau/metadata/naudataset_clean.csv")

metadata["image_path"] = metadata["nama_gambar"].apply(
    lambda x: os.path.join(IMAGE_FOLDER, x)
)

missing = metadata[
    ~metadata["image_path"].apply(os.path.exists)
]

print(len(missing))
# Out:
# 0

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# True
# Tesla T4

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# True
# Tesla T4

# %%
import torch

print(torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())
# Out:
# 2.13.0+cu130
# CUDA available: True
# CUDA device count: 1

# %%
import torch

print("CUDA :", torch.cuda.is_available())
print("Device :", torch.cuda.get_device_name(0))
# Out:
# CUDA : True
# Device : Tesla T4

# %%
import os
import torch
import numpy as np
import pandas as pd

from PIL import Image
from tqdm import tqdm

# %%
# !pip install -q transformers accelerate timm safetensors

# %%
# !pip install -q ftfy open_clip_torch

# %%
# !pip install -U \
transformers \
torch \
torchvision \
timm \
ftfy \
open_clip_torch \
accelerate \
safetensors
# Out:
# ...
#   Using cached transformers-5.14.1-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached huggingface_hub-1.25.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# ...
# Using cached transformers-5.14.1-py3-none-any.whl (11.6 MB)
# Using cached huggingface_hub-1.25.1-py3-none-any.whl (774 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 0.36.2
#     Uninstalling huggingface_hub-0.36.2:
#       Successfully uninstalled huggingface_hub-0.36.2
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.4
#     Uninstalling tokenizers-0.21.4:
#       Successfully uninstalled tokenizers-0.21.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0
#     Uninstalling transformers-4.49.0:
# ...

# %%
import ftfy
import open_clip

print("OK")
# Out:
# OK

# %%
import sys
print(sys.version)

import torch
print(torch.__version__)

import transformers
print(transformers.__version__)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2.13.0+cu130
# 5.14.1

# %%
# !pip uninstall -y transformers
# !pip install transformers==4.49.0
# !pip install ftfy open_clip_torch timm
# Out:
# WARNING: Skipping transformers as it is not installed.
# ...
#   Using cached transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
# Using cached transformers-4.49.0-py3-none-any.whl (10.0 MB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.25.1
#     Uninstalling huggingface_hub-1.25.1:
#       Successfully uninstalled huggingface_hub-1.25.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
# ...

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.49.0

# %%
# !pip install -q \
open_clip_torch \
ftfy \
timm \
pillow \
faiss-gpu-cu12

# %%
import torch
import open_clip

from PIL import Image

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model, preprocess, _ = open_clip.create_model_and_transforms(
    "hf-hub:Marqo/marqo-fashionSigLIP"
)

model = model.to(device)
model.eval()

tokenizer = open_clip.get_tokenizer(
    "hf-hub:Marqo/marqo-fashionSigLIP"
)

print("Model Loaded!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Model Loaded!

# %%
img_path = metadata.iloc[0]["image_path"]

image = preprocess(
    Image.open(img_path).convert("RGB")
).unsqueeze(0)

image = image.to(device)

# %%
with torch.no_grad():

    image_embedding = model.encode_image(
        image,
        normalize=True
    )

print(image_embedding.shape)
# Out:
# torch.Size([1, 768])

# %%
embedding = image_embedding.cpu().numpy()

print(embedding.shape)
# Out:
# (1, 768)

# %%
from utils.embedding import FashionEmbedding

embedder = FashionEmbedding()

vector = embedder.encode_image(
    metadata.iloc[0]["image_path"]
)

print(vector.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_24664/1027540030.py in <cell line: 0>()
# ----> 1 from utils.embedding import FashionEmbedding
#       2
#       3 embedder = FashionEmbedding()
#       4
#       5 vector = embedder.encode_image(
#
# ModuleNotFoundError: No module named 'utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os

print(os.getcwd())
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !ls -R
# Out:
# .:
# drive  sample_data
#
# ./drive:
# MyDrive
#
# ./drive/MyDrive:
#  07a9ad55-352c-48f5-89d7-ff17800ec622.jpeg
#  100486635434376312.jpg
#  1005358316836499625.jpg
#  1005358316837148571.jpg
#  100697741665531928.jpg
#  100697741665545766.jpg
#  100768110401064927.jpg
#  1008384172834482798.jpg
#  1013872934861092815.jpg
#  10203536651858280.jpg
#  10203536652435988.jpg
#  1021894971669865101.jpg
#  10273905392490217.jpg
#  10273905395752409.jpg
#  1030128114779601569.jpg
#  1039698263968986514.jpg
# '10414642881410610 (1).jpg'
#  10414642881410610.jpg
#  1046383294692093440.jpg
#  1047016613501406475.jpg
#  1053701644047913944.jpg
#  105553185012318913.jpg
#  105553185012559556.jpg
#  1055599907425210.jpg
#  1055599907739154.jpg
#  1055742337635011066.jpg
#  1072419730028091821.jpg
#  1081004716824908792.jpg
#  10836855347137496.jpg
#  1092193347153239930.jpg
#  109423465942427349.jpg
#  1095641415625083994.jpg
#  1095641415625156180.jpg
#  1095641415625324572.jpg
# ...
